# %% [markdown]
# # Data Science Capstone Project Report
#
# **Project:** SpaceX Falcon 9 First Stage Landing Prediction
# **Course:** IBM Applied Data Science Capstone
# **Student Name:** `<your name>`
# **GitHub Repository:** `<paste your GitHub URL here>`
#
# > This notebook is a report template. Replace all placeholders with your own completed lab outputs, charts, screenshots, and explanations before exporting to PDF.

# %% [markdown]
# ## Submission Checklist
#
# Use this checklist before exporting to PDF:
#
# - [ ] GitHub project URL included
# - [ ] Executive Summary slide/section completed
# - [ ] Introduction and problem statement completed
# - [ ] Data Collection using SpaceX API explained
# - [ ] Data Collection using Web Scraping explained
# - [ ] Data Wrangling methodology explained
# - [ ] EDA visualizations included: scatter plots, bar charts, yearly trends
# - [ ] EDA with SQL results included: launch sites, payloads, success rates, rankings, time analysis
# - [ ] Folium map results included: launch site markers, launch records, proximity analysis
# - [ ] Plotly Dash results included: success pie charts and payload vs. outcome scatter plots
# - [ ] Predictive analysis included: multiple models, metrics, confusion matrix, best model explanation
# - [ ] Clear final conclusion included

# %% [markdown]
# ## 1. Executive Summary
#
# Write a short summary of the full project here.
#
# Include:
#
# - The business/scientific problem
# - Data sources used
# - Main data science methods used
# - Key results from EDA
# - Best machine learning model and performance
# - Final conclusion
#
# **Example structure:**
#
# This project predicts whether the SpaceX Falcon 9 first stage will successfully land after launch. Data was collected using the SpaceX API and web scraping. After data wrangling, exploratory analysis, SQL analysis, interactive maps, dashboards, and machine learning models were applied. The best model was selected based on evaluation metrics such as accuracy, precision, recall, F1-score, and confusion matrix results.

# %% [markdown]
# ## 2. Introduction
#
# ### Project Background
#
# SpaceX advertises Falcon 9 launches at a lower cost than many competitors because the first stage can sometimes be reused. Predicting whether the first stage will land successfully can help estimate launch cost and mission risk.
#
# ### Problem Statement
#
# The goal is to build a data science pipeline that predicts the success of Falcon 9 first-stage landing using historical launch data.
#
# ### Main Question
#
# Can historical launch information such as launch site, payload mass, orbit type, booster version, and flight number be used to predict first-stage landing success?

# %% [markdown]
# ## 3. Data Collection — SpaceX API
#
# Explain the API collection process here.
#
# Include:
#
# - API endpoint used
# - What fields were collected
# - How nested JSON data was normalized
# - GitHub URL to the notebook/code

# %%
# Data Collection from SpaceX API - Template
# Run this only in an environment with internet access.

import requests
import pandas as pd

SPACEX_API_URL = "https://api.spacexdata.com/v4/launches/past"

# TODO: Uncomment and run in your own notebook/lab environment
# response = requests.get(SPACEX_API_URL)
# data = response.json()
# df_api = pd.json_normalize(data)
# df_api.head()

# %% [markdown]
# ### API Data Collection Notes
#
# Write your explanation here:
#
# - Number of records collected: `<your value>`
# - Important columns extracted: `<your columns>`
# - Output file saved as: `<your file name>`

# %% [markdown]
# ## 4. Data Collection — Web Scraping
#
# Explain the web scraping process here.
#
# Include:
#
# - Website/table scraped
# - Python libraries used
# - Steps used to parse the table
# - GitHub URL to the notebook/code

# %%
# Web Scraping - Template
# Run this only in an environment with internet access.

import pandas as pd
from bs4 import BeautifulSoup
import requests

# TODO: Replace with the course-provided URL if different
# url = "https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches"
# html = requests.get(url).text
# soup = BeautifulSoup(html, "html.parser")
# tables = pd.read_html(html)
# df_web = tables[0]
# df_web.head()

# %% [markdown]
# ### Web Scraping Notes
#
# Write your explanation here:
#
# - Source website: `<your URL>`
# - Table/data scraped: `<description>`
# - Cleaning steps needed after scraping: `<your explanation>`

# %% [markdown]
# ## 5. Data Wrangling Methodology
#
# Explain how the raw data was cleaned and prepared.
#
# Include:
#
# - Handling missing values
# - Filtering Falcon 9 records
# - Creating the landing outcome label
# - Encoding categorical variables
# - Selecting final features
# - GitHub URL to the notebook/code

# %%
# Data Wrangling - Template

import pandas as pd
import numpy as np

# TODO: Load your cleaned data file
# df = pd.read_csv("dataset_part_2.csv")

# Example checks:
# df.info()
# df.isnull().sum()
# df.describe(include="all")

# TODO: Create or verify target column
# Example:
# df["Class"] = df["Outcome"].apply(lambda x: 1 if x == "True ASDS" or x == "True RTLS" else 0)

# %% [markdown]
# ### Data Wrangling Summary
#
# Write your results here:
#
# - Final number of rows: `<your value>`
# - Final number of columns: `<your value>`
# - Target variable: `<your target variable>`
# - Success class meaning: `<your explanation>`

# %% [markdown]
# ## 6. Exploratory Data Analysis with Visualization
#
# Include required visualization results here.
#
# Required examples:
#
# - Scatter plot: Flight Number vs Payload Mass, colored by landing outcome
# - Scatter plot: Payload Mass vs Launch Site, colored by landing outcome
# - Bar chart: Success rate by orbit type
# - Line chart: Yearly launch success trend
# - Any other important chart from your lab

# %%
# EDA Visualizations - Template

import matplotlib.pyplot as plt

# TODO: Load your wrangled data
# df = pd.read_csv("dataset_part_2.csv")

# Example scatter plot template:
# plt.figure(figsize=(8, 5))
# plt.scatter(df["FlightNumber"], df["PayloadMass"], c=df["Class"])
# plt.xlabel("Flight Number")
# plt.ylabel("Payload Mass")
# plt.title("Flight Number vs Payload Mass by Landing Outcome")
# plt.show()

# Example yearly trend template:
# df["Date"] = pd.to_datetime(df["Date"])
# df["Year"] = df["Date"].dt.year
# yearly_success = df.groupby("Year")["Class"].mean()
# yearly_success.plot(kind="line", marker="o", figsize=(8, 5))
# plt.xlabel("Year")
# plt.ylabel("Success Rate")
# plt.title("Yearly Launch Success Trend")
# plt.show()

# %% [markdown]
# ### EDA Visualization Findings
#
# Write your findings here:
#
# 1. `<finding from scatter plot>`
# 2. `<finding from bar chart>`
# 3. `<finding from yearly trend>`

# %% [markdown]
# ## 7. Exploratory Data Analysis with SQL
#
# Summarize SQL queries and results.
#
# Include results for:
#
# - Unique launch sites
# - Payload mass analysis
# - Success rate analysis
# - Booster version/category ranking
# - Time/date-based analysis
# - GitHub URL to the notebook/code

# %%
# SQL EDA - Template

import sqlite3
import pandas as pd

# TODO: Load your data and create SQLite database
# df = pd.read_csv("Spacex.csv")
# conn = sqlite3.connect("spacex.db")
# df.to_sql("SPACEXTBL", conn, if_exists="replace", index=False)

# Example query template:
# query = """
# SELECT Launch_Site, COUNT(*) AS total_launches
# FROM SPACEXTBL
# GROUP BY Launch_Site
# ORDER BY total_launches DESC;
# """
# pd.read_sql(query, conn)

# %% [markdown]
# ### SQL Findings
#
# Write your SQL findings here:
#
# - Launch site with most launches: `<your answer>`
# - Payload pattern: `<your answer>`
# - Success rate pattern: `<your answer>`
# - Time-based trend: `<your answer>`

# %% [markdown]
# ## 8. Interactive Visual Analytics — Folium Map
#
# Add screenshots or outputs from your Folium map lab.
#
# Include:
#
# - Launch site markers
# - Launch outcome markers
# - Distance/proximity analysis
# - GitHub URL to the notebook/code

# %%
# Folium Map - Template
# Run in a notebook environment with folium installed.

# import folium
# import pandas as pd

# TODO: Load launch site location data
# launch_sites_df = pd.read_csv("spacex_launch_geo.csv")

# Example map template:
# nasa_coordinate = [29.559684888503615, -95.0830971930759]
# site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
# site_map

# %% [markdown]
# ### Folium Findings
#
# Write your map findings here:
#
# - Important geographic pattern: `<your finding>`
# - Nearby infrastructure observed: `<your finding>`
# - Launch site comparison: `<your finding>`

# %% [markdown]
# ## 9. Interactive Visual Analytics — Plotly Dash Dashboard
#
# Add screenshots or descriptions from your dashboard.
#
# Include:
#
# - Success pie chart by launch site
# - Payload vs launch outcome scatter plot
# - Filters/dropdowns used
# - GitHub URL to the dashboard code

# %%
# Plotly Dash Dashboard - Template
# Run as a .py file or in a supported notebook environment.

# from dash import Dash, dcc, html, Input, Output
# import plotly.express as px
# import pandas as pd

# TODO: Load dashboard dataset
# spacex_df = pd.read_csv("spacex_launch_dash.csv")

# app = Dash(__name__)
# app.layout = html.Div([
#     html.H1("SpaceX Launch Records Dashboard"),
#     dcc.Dropdown(id="site-dropdown"),
#     dcc.Graph(id="success-pie-chart"),
#     dcc.Graph(id="success-payload-scatter-chart")
# ])

# TODO: Add callbacks from your completed lab

# %% [markdown]
# ### Dashboard Findings
#
# Write your dashboard findings here:
#
# - Best launch site by success rate: `<your answer>`
# - Payload range with highest success: `<your answer>`
# - Important pattern from scatter chart: `<your answer>`

# %% [markdown]
# ## 10. Predictive Analysis
#
# Build and compare multiple machine learning models.
#
# Required content:
#
# - Train/test split
# - Standardization or preprocessing
# - Multiple models tested
# - Model evaluation results
# - Confusion matrix
# - Best model explanation
# - Final prediction conclusion

# %%
# Predictive Analysis - Template

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# TODO: Load your prepared feature data
# X = pd.read_csv("features.csv")
# y = pd.read_csv("target.csv").values.ravel()

# Example split:
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2, stratify=y)

# Example scaling:
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)

# Example model list:
# models = {
#     "Logistic Regression": LogisticRegression(max_iter=1000),
#     "SVM": SVC(),
#     "Decision Tree": DecisionTreeClassifier(random_state=2),
#     "KNN": KNeighborsClassifier()
# }

# TODO: Train and evaluate your models

# %%
# Model Evaluation Table - Template

# results = []
# for name, model in models.items():
#     model.fit(X_train_scaled, y_train)
#     y_pred = model.predict(X_test_scaled)
#     results.append({
#         "Model": name,
#         "Accuracy": accuracy_score(y_test, y_pred),
#         "Precision": precision_score(y_test, y_pred, zero_division=0),
#         "Recall": recall_score(y_test, y_pred, zero_division=0),
#         "F1 Score": f1_score(y_test, y_pred, zero_division=0)
#     })
#
# results_df = pd.DataFrame(results)
# results_df

# %%
# Confusion Matrix - Template

# best_model_name = "<replace with your best model>"
# best_model = models[best_model_name]
# y_pred_best = best_model.predict(X_test_scaled)
# cm = confusion_matrix(y_test, y_pred_best)
# cm

# %% [markdown]
# ### Predictive Analysis Results
#
# Fill in your results:
#
# | Model | Accuracy | Precision | Recall | F1 Score |
# |---|---:|---:|---:|---:|
# | Logistic Regression | `<value>` | `<value>` | `<value>` | `<value>` |
# | SVM | `<value>` | `<value>` | `<value>` | `<value>` |
# | Decision Tree | `<value>` | `<value>` | `<value>` | `<value>` |
# | KNN | `<value>` | `<value>` | `<value>` | `<value>` |
#
# **Best Model:** `<your best model>`
#
# **Reason:** `<explain why this model was selected>`

# %% [markdown]
# ## 11. Final Conclusion
#
# Write your final conclusion here.
#
# Include:
#
# - Main variables that affected landing success
# - Best-performing launch site or pattern observed
# - Best machine learning model
# - Final recommendation or business insight
#
# **Conclusion template:**
#
# The project showed that Falcon 9 first-stage landing success can be predicted using historical launch data. Exploratory analysis showed that variables such as launch site, payload mass, orbit, and flight number are related to successful landings. After comparing multiple machine learning models, `<best model>` performed best based on `<metric>`. These findings can help estimate launch cost and support future launch planning.

# %% [markdown]
# ## 12. References
#
# Add references here:
#
# - SpaceX API
# - Wikipedia launch data page
# - IBM course labs
# - GitHub repository
# - Any additional resources used

# %% [markdown]
# ## Export Instructions
#
# After filling in all sections and running the required cells:
#
# 1. Save this notebook.
# 2. Export or print it as PDF.
# 3. Name the final PDF: **Data Science Capstone Project Report.pdf**
# 4. Upload the PDF in the final assignment page.
